# %%
import pandas as pd

# %%
data = pd.read_csv('Final.csv', encoding='utf-8', skiprows=[0], header=None)

# %%
test = data[2].values.tolist()
print test
print len(test)
# Out:
# [u'ffen43894404', u'fkjp85595168', u'fhjp83987809', u'fnin45286444', u'ftde25432188', u'fden34160708', u'fajp45294966', u'fben74853102', u'fpfr95096628', u'ffen94125856', u'flen44786282', u'fzen05446858', u'fycn55311514', u'fsjp55309954', u'fden55154896', u'fech25007060', u'fgen42404233', u'fren35065822', u'fufr64699388', u'fdcn27532947', u'ftth35563194', u'fase74080728', u'fmit54703676', u'fpit54901306', u'foen24361050', u'fwno43616916', u'fves24334482', u'fffr63854770', u'fojp85251328', u'fwtw44688586', u'fdjp93547955', u'frjp74671274', u'fwen33832914', u'fldk43841424', u'fttw56869493', u'flde64176826', u'foen33702652', u'fwen64897822', u'fved04721400', u'fcjp44900708', u'fttw58023109', u'fpde44193400', u'fwjp54851852', u'fben04264426', u'fken04139124', u'fcjp95462882', u'fbjp54840686', u'fsen44034354', u'fmen34824302', u'fejp44842648', u'fdtw59562402', u'fijp24842814', u'fsjp94807908', u'fwtw64996668', u'fmfi22534634', u'fsen53263904', u'fazh49460875', u'ftjp74717204', u'fgen63631
# ...

# %%
data2 = pd.read_csv('atmovie.csv', encoding='utf-8', skiprows=[0], header=None)

# %%
x = data2[0].values.tolist()
print x
# Out:
# [u'fwen30283832', u'ften50325703', u'fCen40816462', u'ften00407265', u'frus31839492', u'fdtw20284066', u'fefr80307156', u'fmen00288045', u'fien70327919', u'fken41448755', u'fuen00365885', u'fBen00285462', u'fwsg46737223', u'fpen90325980', u'fben00402057', u'fnen50446750', u'fuen40467110', u'fsen00324127', u'fien40897361', u'faen62395427', u'fpen00438315', u'fhen50411477', u'fgen90473360', u'fFen00264616', u'fajp60488870', u'fgen00333766', u'fCel40317248', u'fpus53450650', u'faen51456520', u'feen00283530', u'fien51058017', u'fhen90295297', u'fTen90268690', u'fien40309698', u'fcen42389182', u'fbfr42402623', u'fDen00259288', u'fwen20910970', u'ffen00493459', u'fyen50403702', u'foen00046852', u'ffen40426459', u'fden01560985', u'fken60481536', u'fmfr54085084', u'faen00368578', u'fpen50414387', u'fWen00281358', u'faen50364961', u'fien00420609', u'fsge40277327', u'fben11126591', u'frin52265171', u'ftfr50841044', u'ffen52258345', u'fben31126590', u'fben00401997', u'faen40384814', u'fait32290
# ...

# %%
# aaa = []
# for y in test:
# #    print y
#     if y in x:
#         count += 1
#         print x
#         print y
#         aaa.append(y)
# print aaa
# print len(aaa)
worddic = {}
for y in test:    
    if y not in worddic:
        worddic[y] = 1
    else:
        worddic[y] = worddic[y] + 1
print worddic
# Out:
# {u'fgen00252480': 1, u'fIde41360976': 1, u'fwtw39706061': 1, u'fsen70165982': 1, u'fsen40839980': 1, u'fjen61634122': 1, u'fenG00279111': 1, u'fpen60236640': 1, u'fcen40374563': 1, u'ften81456941': 1, u'fven51686821': 1, u'fjen80401729': 1, u'foel50368913': 1, u'fsjp22358444': 1, u'fsen00287963': 1, u'fbpl54358230': 1, u'ffen80432283': 1, u'flen51440161': 1, u'fhen30366548': 1, u'fpen91854564': 1, u'f1en11190080': 1, u'fpfr50948535': 1, u'fpen60316396': 1, u'fben33174376': 1, u'fven30338526': 1, u'fses52955316': 1, u'fous40790724': 1, u'fRen00831884': 1, u'ften52172934': 1, u'fuen51659343': 1, u'fuen40880578': 1, u'fben41559547': 1, u'fTen41103275': 1, u'fcen21584016': 1, u'frfr20783767': 1, u'fsen32053463': 1, u'fhen40468492': 1, u'fpus42109184': 1, u'fken40443559': 1, u'fMen00269499': 1, u'fmsi51305907': 1, u'fCen00275022': 1, u'fmen41568338': 1, u'faen71602098': 1, u'fhen42243537': 1, u'fdes23147312': 1, u'fien61080016': 1, u'fQen21082868': 1, u'fvde41611211': 1, u'fpen50395251': 
# ...
